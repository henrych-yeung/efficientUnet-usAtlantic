# %% [markdown]
# Author: Henry CH Yeung

# %% [markdown]
# ### Postprocessing of Tree Crown Segmentation

# %%
import os
import rasterio
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/apm5rt/Library/CloudStorage/OneDrive-UniversityofVirginia/deepLearning/dryland_U-Net_NorthCarolinaTest/notebooks/scripts'

# %%
# Import dataset
dataset = rasterio.open('../../prediction/det_m_3507517_sw_18_060_20200516.tif')
label_ori = dataset.read()

# %%
label_ori_subset = label_ori[0,11030:11300,2300:2500]

# %%
# 1. Distance Transformation
# Calculate euclidean distance of every pixel from the crown edge 
eucliDist = cv2.DIST_L2
distTransform = cv2.distanceTransform(label_ori_subset, distanceType=eucliDist, maskSize=3, dstType=cv2.CV_8U)
# plt.imshow(distTransform)
# plt.colorbar()

# %%
# 2. Locate Instance Center (i.e. Tree crown center with the highest euclidean distance from the crown edge)
# Slide a maximum filter across the distance transform image
winsize = 6 # Depends on the smallest tree in the image
winshape = cv2.MORPH_RECT
kernel = cv2.getStructuringElement(winshape, (winsize,winsize))
dilation = cv2.dilate(distTransform, kernel) #erode;dilate = min;max filter

# If a pixel has the same euclidean distance in both dilation and distTransform image, it is assigned as the instance center
binary = (distTransform == dilation).astype(np.uint8)
instanceCenter = binary * label_ori_subset # avoid classifying pixels = 0 as instance center
instanceCenter = (instanceCenter > 0).astype(np.uint8)

# %%
# plt.subplots(figsize=(15,15))
# plt.imshow(instanceCenter)

# %%
# Plot graph
fig, ax = plt.subplots(1,4, figsize=(9, 5))
ax[0].imshow(label_ori_subset)
ax[1].imshow(distTransform)
ax[2].imshow(max_image)
ax[3].imshow(instanceCenter)
fig.tight_layout()

# %%
# # Plot graph
# fig, ax = plt.subplots(1,2, figsize=(10, 6))
# ax[0].imshow(label_ori_subset)
# ax[1].imshow(instanceCenter)
# fig.tight_layout()

# %%
connectivity = 8
# Perform the operation
output = cv2.connectedComponentsWithStats(instanceCenter, connectivity, cv2.CV_32S)

# Get the results
# The first cell is the number of labels
num_labels = output[0]
# The second cell is the label matrix
labels = output[1]
# The third cell is the stat matrix
stats = output[2]
# The fourth cell is the centroid matrix
centroids = output[3]

# %%
plt.subplots(figsize=(15,15))
plt.imshow(label_ori_subset)
for p,q in centroids:
    x_cord = p # try this change (p and q are already the coordinates)
    y_cord = q
    plt.scatter([x_cord], [y_cord], s=2, c='r')
plt.show()

# %%
fig,ax = plt.subplots(1,1, figsize=(10,10))
plt.axis('off')
ax.imshow(label_ori_subset,cmap='gray')
centroids = np.zeros(shape=(len(np.unique(labels)),2)) # Access the coordinates of centroids
for i,prop in enumerate(props):
    my_centroid = prop.centroid
    centroids[i,:]= my_centroid
    ax.plot(my_centroid[1],my_centroid[0],'r.')

# print(centroids)
# fig.savefig('out.png', bbox_inches='tight', pad_inches=0)
plt.show()
